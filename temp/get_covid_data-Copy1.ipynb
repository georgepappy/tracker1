# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

# %%
# Make some room to see stuff (i.e. drop display limits on Pandas rows & cols - be careful w/ big df's!)

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### The method/code below using BeautifulSoup to access all .csv files in a GitHub Repository is adapted from:
#
# https://stackoverflow.com/questions/69806371/combining-all-csv-files-from-github-repository-link-and-make-it-a-one-csv-file

# %% [markdown]
# # 1) State Data

# %%
con = sqlite3.connect('test.db')

# %%
html = requests.get('https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports_us')

for link in BeautifulSoup(html.text, parse_only=SoupStrainer('a')):
    if hasattr(link, 'href') and link['href'].endswith('.csv'):
        url = 'https://github.com'+link['href'].replace('/blob/', '/raw/')
        df = pd.read_csv(url, sep=',', lineterminator='\n')
        
        # Drop rows we're not interested in (e.g. The Cruise Ships with outbreaks, Minor Outlying US Territories)
        df = df[~df['Province_State'].isin(['Diamond Princess', 'Grand Princess', 'American Samoa', 'Recovered', 
                                            'Virgin Islands', 'Guam', 'Northern Mariana Islands'])]
        
        # Account for slight modifications to column nomenclature that occurred over time
        if 'Mortality_Rate' in df.columns:
            df.rename({'Mortality_Rate' : 'Case_Fatality_Ratio', 'People_Tested' : 'Total_Test_Results'}, axis=1, inplace=True)

        # Retain only columns of interest
        df = df.iloc[:, 0:14].drop(columns=['Recovered', 'Active', 'FIPS', 'Total_Test_Results', 'People_Hospitalized'])
        
        # drop data into database
        df.to_sql('state_data', con, if_exists='append', index=False)

# %%
con.close()

# %%
'''
SELECT * FROM state_data 
WHERE Province_State IS NULL
OR Last_Update IS NULL
OR Lat IS NULL
OR Long_ IS NULL
OR Confirmed IS NULL
OR Deaths IS NULL
OR Incident_Rate IS NULL
OR Case_Fatality_Ratio IS NULL;
'''

# %% [markdown]
# # 2) City Data

# %%
largest_200 = pd.read_csv('largest_200_us_cities.csv')
largest_200 = largest_200[['name', 'usps', 'pop2021']]

# %%
largest_200.head()
# Out:
#          name usps  pop2021
# 0   Anchorage   AK   282958
# 1  Birmingham   AL   207235
# 2  Huntsville   AL   205472
# 3  Montgomery   AL   197777
# 4      Mobile   AL   186542

# %%
# Up to 5 (large states like CA, FL, TX; smaller states may have as few as 0 in the largest 200 - will have to add at least 1 for these)

largest_per_state = largest_200.set_index('name').groupby('usps')['pop2021'].nlargest(5).reset_index()
largest_per_state.head()
# Out:
#   usps        name  pop2021
# 0   AK   Anchorage   282958
# 1   AL  Birmingham   207235
# 2   AL  Huntsville   205472
# 3   AL  Montgomery   197777
# 4   AL      Mobile   186542

# %%
largest_per_state['usps'].unique().shape
# Out:
# (43,)

# %%
state_postal_codes = pd.read_csv('state_postal_codes.csv')[['State', 'Code']]
print(state_postal_codes.shape)
state_postal_codes.head()
# Out:
# (51, 2)
#         State Code
# 0     Alabama   AL
# 1      Alaska   AK
# 2     Arizona   AZ
# 3    Arkansas   AR
# 4  California   CA

# %%
state_postal_codes = pd.concat([state_postal_codes, pd.DataFrame({'State' : ['Puerto Rico'], 'Code' : ['PR']})], axis=0).reset_index(drop=True)
state_postal_codes.shape
# Out:
# (52, 2)

# %%
np.setdiff1d(state_postal_codes['Code'], largest_per_state['usps'].unique())
# Out:
# array(['DE', 'ME', 'MT', 'ND', 'NH', 'SC', 'VT', 'WV', 'WY'], dtype=object)

# %%
# Will just manually insert the single largest city & population for these states that didn't have a city in the top 200 (above)

small_state_largest = pd.DataFrame({'usps' : np.setdiff1d(state_postal_codes['Code'], largest_per_state['usps'].unique()),
                                    'name' : ['Wilmington', 'Portland', 'Billings', 'Fargo', 'Manchester', 'Charleston', 'Burlington', 'Charleston', 'Cheyenne'],
                                    'pop2021' : [69584, 65835, 109843, 125804, 113035, 140476, 43063, 45264, 65035]})
small_state_largest
# Out:
#   usps        name  pop2021
# 0   DE  Wilmington    69584
# 1   ME    Portland    65835
# 2   MT    Billings   109843
# 3   ND       Fargo   125804
# 4   NH  Manchester   113035
# 5   SC  Charleston   140476
# 6   VT  Burlington    43063
# 7   WV  Charleston    45264
# 8   WY    Cheyenne    65035

# %%
largest_per_state = pd.concat([largest_per_state, small_state_largest], axis=0).reset_index(drop=True)
print(largest_per_state.shape)
largest_per_state.head()
# Out:
# (132, 3)
#   usps        name  pop2021
# 0   AK   Anchorage   282958
# 1   AL  Birmingham   207235
# 2   AL  Huntsville   205472
# 3   AL  Montgomery   197777
# 4   AL      Mobile   186542

# %%
# This makes sense: 50 states + DC + Puerto Rico = 52

largest_per_state['usps'].unique().shape
# Out:
# (52,)

# %%
largest_per_state = largest_per_state.merge(state_postal_codes, how='left', left_on='usps', right_on='Code').drop(columns=['usps', 'Code'])

# %%
print(largest_per_state.shape)
largest_per_state.head()
# Out:
# (132, 3)
#          name  pop2021    State
# 0   Anchorage   282958   Alaska
# 1  Birmingham   207235  Alabama
# 2  Huntsville   205472  Alabama
# 3  Montgomery   197777  Alabama
# 4      Mobile   186542  Alabama

# %%
temp = df[df['Combined_Key'].isin(largest_per_state['Combined_Key'])]
temp = temp[(~temp['Admin2'].isin(['Boise', 'Des Moines', 'Wichita', 'Jackson', 'Lincoln', 'Austin', 'Houston', 'Bayamon', 'San Juan', 'Richmond']))]
temp = temp[['Admin2', 'Province_State']]

# %%
temp = temp.rename({'Admin2' : 'name', 'Province_State' : 'State'}, axis=1).reset_index(drop=True)
temp
# Out:
#               name           State
# 0           Mobile         Alabama
# 1       Montgomery         Alabama
# 2        Anchorage          Alaska
# 3           Fresno      California
# 4      Los Angeles      California
# 5        San Diego      California
# 6    San Francisco      California
# 7           Denver        Colorado
# 8         Honolulu          Hawaii
# 9        Baltimore        Maryland
# 10       Worcester   Massachusetts
# 11     Kansas City        Missouri
# 12       St. Louis        Missouri
# 13          Durham  North Carolina
# 14           Tulsa        Oklahoma
# 15    Philadelphia    Pennsylvania
# 16      Providence    Rhode Island
# 17      Charleston  South Carolina
# 18          Dallas           Texas
# 19       Arlington        Virginia
# 20      Chesapeake        Virginia
# 21         Norfolk        Virginia
# 22  Virginia Beach        Virginia
# 23         Spokane      Washington
# 24       Milwaukee       Wisconsin

# %%
temp.merge(largest_per_state[['name', 'State', 'pop2021']], how='left', on=['name', 'State']).to_csv('cities_of_interest.csv', index=False)

# %%
cities = pd.read_csv('cities_of_interest.csv')
cities
# Out:
#               name           State  pop2021
# 0           Mobile         Alabama   186542
# 1       Montgomery         Alabama   197777
# 2        Anchorage          Alaska   282958
# 3           Fresno      California   537100
# 4      Los Angeles      California  3983540
# 5        San Diego      California  1427720
# 6    San Francisco      California   883255
# 7           Denver        Colorado   749103
# 8         Honolulu          Hawaii   341302
# 9        Baltimore        Maryland   575584
# 10       Worcester   Massachusetts   185174
# 11     Kansas City        Missouri   501957
# 12       St. Louis        Missouri   294890
# 13          Durham  North Carolina   287865
# 14           Tulsa        Oklahoma   402742
# 15    Philadelphia    Pennsylvania  1585010
# 16      Providence    Rhode Island   180609
# 17      Charleston  South Carolina   140476
# 18          Dallas           Texas  1347120
# 19       Arlington        Virginia   233464
# 20      Chesapeake        Virginia   249787
# 21         Norfolk        Virginia   241056
# 22  Virginia Beach        Virginia   450224
# 23         Spokane      Washington   227579
# 24       Milwaukee       Wisconsin   587721

# %%
largest_per_state['Combined_Key'] = largest_per_state['name'] + ', ' + largest_per_state['State'] + ', US'

# %%
largest_per_state.head()
# Out:
#          name  pop2021    State             Combined_Key
# 0   Anchorage   282958   Alaska    Anchorage, Alaska, US
# 1  Birmingham   207235  Alabama  Birmingham, Alabama, US
# 2  Huntsville   205472  Alabama  Huntsville, Alabama, US
# 3  Montgomery   197777  Alabama  Montgomery, Alabama, US
# 4      Mobile   186542  Alabama      Mobile, Alabama, US

# %%
href = 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/'

fname = '01-30-2022.csv'

# %%
df = pd.read_csv(href+fname+'?raw=true', sep=',', lineterminator='\n')

# %%
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2022-01-31 04:21:09  33.93911
# 1   NaN    NaN            NaN        Albania  2022-01-31 04:21:09  41.15330
# 2   NaN    NaN            NaN        Algeria  2022-01-31 04:21:09  28.03390
# 3   NaN    NaN            NaN        Andorra  2022-01-31 04:21:09  42.50630
# 4   NaN    NaN            NaN         Angola  2022-01-31 04:21:09 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     162111    7408        NaN     NaN  Afghanistan
# 1  20.168300     255741    3334        NaN     NaN      Albania
# 2   1.659600     250774    6566        NaN     NaN      Algeria
# 3   1.521800      35556     145        NaN     NaN      Andorra
# 4  17.873900      98076    1895        NaN     NaN       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     416.434392             4.569708
# 1    8886.684273             1.303663
# 2     571.876933             2.618294
# 3   46018.248884             0.407807
# 4     298.409299             1.932175

# %%
print(df.shape)
df[df['Combined_Key'].isin(largest_per_state['Combined_Key'])].shape
# Out:
# (4006, 14)
# (35, 14)

# %%
df[df['Country_Region'] == 'US'].head()
# Out:
#        FIPS   Admin2 Province_State Country_Region          Last_Update  \
# 673  1001.0  Autauga        Alabama             US  2022-01-31 04:21:09
# 674  1003.0  Baldwin        Alabama             US  2022-01-31 04:21:09
# 675  1005.0  Barbour        Alabama             US  2022-01-31 04:21:09
# 676  1007.0     Bibb        Alabama             US  2022-01-31 04:21:09
# 677  1009.0   Blount        Alabama             US  2022-01-31 04:21:09
#
#            Lat      Long_  Confirmed  Deaths  Recovered  Active  \
# 673  32.539527 -86.644082      14498     166        NaN     NaN
# 674  30.727750 -87.722071      52459     612        NaN     NaN
# 675  31.868263 -85.387129       5241      84        NaN     NaN
# 676  32.996421 -87.125115       6088      96        NaN     NaN
# 677  33.982109 -86.567906      13981     207        NaN     NaN
#
#              Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 673  Autauga, Alabama, US   25949.990156             1.144986
# 674  Baldwin, Alabama, US   23499.556519             1.166625
# 675  Barbour, Alabama, US   21230.657053             1.602748
# 676     Bibb, Alabama, US   27185.853354             1.576873
# 677   Blount, Alabama, US   24177.705530             1.480581

# %%
df[df['Combined_Key'].isin(largest_per_state['Combined_Key'])]
# Out:
#          FIPS          Admin2  Province_State Country_Region  \
# 721    1097.0          Mobile         Alabama             US
# 723    1101.0      Montgomery         Alabama             US
# 744    2020.0       Anchorage          Alaska             US
# 876    6019.0          Fresno      California             US
# 885    6037.0     Los Angeles      California             US
# 904    6073.0       San Diego      California             US
# 905    6075.0   San Francisco      California             US
# 943    8031.0          Denver        Colorado             US
# 1240  15003.0        Honolulu          Hawaii             US
# 1252  16015.0           Boise           Idaho             US
# 1515  19057.0      Des Moines            Iowa             US
# 1690  20203.0         Wichita          Kansas             US
# 1901  24005.0       Baltimore        Maryland             US
# 1937  25027.0       Worcester   Massachusetts             US
# 2142  28059.0         Jackson     Mississippi             US
# 2247      NaN     Kansas City        Missouri             US
# 2297  29189.0       St. Louis        Missouri             US
# 2425  31111.0         Lincoln        Nebraska             US
# 2644  37063.0          Durham  North Carolina             US
# 2930  40143.0           Tulsa        Oklahoma             US
# 3024  42101.0    Philadelphia    Pennsylvania             US
# 3052  72021.0         Bayamon     Puerto Rico             US
# 3107  72127.0        San Juan     Puerto Rico             US
# 3126  44007.0      Providence    Rhode Island             US
# 3138  45019.0      Charleston  South Carolina             US
# 3347  48015.0          Austin           Texas             US
# 3396  48113.0          Dallas           Texas             US
# 3452  48225.0         Houston           Texas             US
# 3632  51013.0       Arlington        Virginia             US
# 3649  51550.0      Chesapeake        Virginia             US
# 3710  51710.0         Norfolk        Virginia             US
# 3729  51159.0        Richmond        Virginia             US
# 3749  51810.0  Virginia Beach        Virginia             US
# 3790  53063.0         Spokane      Washington             US
# 3895  55079.0       Milwaukee       Wisconsin             US
#
#               Last_Update        Lat       Long_  Confirmed  Deaths  \
# 721   2022-01-31 04:21:09  30.784723  -88.208424     106905    1459
# 723   2022-01-31 04:21:09  32.220683  -86.209693      51697     812
# 744   2022-01-31 04:21:09  61.149982 -149.142699      91161     468
# 876   2022-01-31 04:21:09  36.757339 -119.646695     220181    2457
# 885   2022-01-31 04:21:09  34.308284 -118.228241    2648751   28923
# 2247        NaN     NaN       Kansas City, Missouri, US   21913.188245
# 2297        NaN     NaN         St. Louis, Missouri, US   21051.191656
# 2425        NaN     NaN           Lincoln, Nebraska, US   22478.089019
# 2644        NaN     NaN      Durham, North Carolina, US   19664.497586
# 2930        NaN     NaN             Tulsa, Oklahoma, US   23042.826973
# 3024        NaN     NaN  Philadelphia, Pennsylvania, US   18675.823704
# 3052        NaN     NaN        Bayamon, Puerto Rico, US   17578.528851
# 3107        NaN     NaN       San Juan, Puerto Rico, US   16754.438028
# 3126        NaN     NaN    Providence, Rhode Island, US   31798.112785
# 3138        NaN     NaN  Charleston, South Carolina, US   25157.387107
# 3347        NaN     NaN               Austin, Texas, US   17048.481620
# 3396        NaN     NaN               Dallas, Texas, US   20569.520352
# 3452        NaN     NaN              Houston, Texas, US   15769.766632
# 3632        NaN     NaN         Arlington, Virginia, US   15879.362613
# 3649        NaN     NaN        Chesapeake, Virginia, US   19134.927604
# 3710        NaN     NaN           Norfolk, Virginia, US   16227.517282
# 3729        NaN     NaN          Richmond, Virginia, US   26532.195500
# 3749        NaN     NaN    Virginia Beach, Virginia, US   18743.749639
# 3790        NaN     NaN         Spokane, Washington, US   21208.765144
# 3895        NaN     NaN        Milwaukee, Wisconsin, US   27413.119656
#
#       Case_Fatality_Ratio
# 721              1.364763
# 723              1.570691
# 744              0.513377
# 876              1.115900
# 885              1.091949
# 904              0.639469
# 905              0.595646
# 943              0.747317
# 1240             0.571444
# 1252             1.345756
# 1515             1.444949
# 1690             1.684211
# 1901             1.825452
# 1937             1.541028
# 2142             1.182837
# 2247             0.993999
# 2297             1.416203
# 2425             0.764526
# 2644             0.450814
# 2930             1.252198
# 3024             1.576206
# 3052             0.000000
# 3107             0.000000
# 3126             1.155202
# 3138             0.769090
# 3347             1.171875
# 3396             1.113974
# 3452             2.650469
# 3632             0.771092
# 3649             0.826058
# 3710             0.946917
# 3729             0.710109
# 3749             0.765929
# 3790             1.090378
# 3895             0.756018

# %%
df[df['Combined_Key'].isin(largest_per_state['Combined_Key'])]
# Out:
#          FIPS          Admin2  Province_State Country_Region  \
# 721    1097.0          Mobile         Alabama             US
# 723    1101.0      Montgomery         Alabama             US
# 744    2020.0       Anchorage          Alaska             US
# 876    6019.0          Fresno      California             US
# 885    6037.0     Los Angeles      California             US
# 904    6073.0       San Diego      California             US
# 905    6075.0   San Francisco      California             US
# 943    8031.0          Denver        Colorado             US
# 1240  15003.0        Honolulu          Hawaii             US
# 1252  16015.0           Boise           Idaho             US
# 1515  19057.0      Des Moines            Iowa             US
# 1690  20203.0         Wichita          Kansas             US
# 1901  24005.0       Baltimore        Maryland             US
# 1937  25027.0       Worcester   Massachusetts             US
# 2142  28059.0         Jackson     Mississippi             US
# 2247      NaN     Kansas City        Missouri             US
# 2297  29189.0       St. Louis        Missouri             US
# 2425  31111.0         Lincoln        Nebraska             US
# 2644  37063.0          Durham  North Carolina             US
# 2930  40143.0           Tulsa        Oklahoma             US
# 3024  42101.0    Philadelphia    Pennsylvania             US
#
#       Recovered  Active                    Combined_Key  Incident_Rate  \
# 721         NaN     NaN             Mobile, Alabama, US   21946.225890
# 723         NaN     NaN         Montgomery, Alabama, US   19674.505267
# 744         NaN     NaN           Anchorage, Alaska, US   25271.527778
# 876         NaN     NaN          Fresno, California, US   17713.924818
# 885         NaN     NaN     Los Angeles, California, US   20784.527947
# 904         NaN     NaN       San Diego, California, US   16866.666866
# 905         NaN     NaN   San Francisco, California, US   10001.372584
# 943         NaN     NaN            Denver, Colorado, US   19134.611550
# 1240        NaN     NaN            Honolulu, Hawaii, US   11203.482997
# 1252        NaN     NaN                Boise, Idaho, US   11148.001532
# 1515        NaN     NaN            Des Moines, Iowa, US   20034.901327
# 1690        NaN     NaN             Wichita, Kansas, US   17272.298254
# 1901        NaN     NaN         Baltimore, Maryland, US   13937.778745
# 1937        NaN     NaN    Worcester, Massachusetts, US   18667.095261
# 2142        NaN     NaN        Jackson, Mississippi, US   19920.343692
# 2247        NaN     NaN       Kansas City, Missouri, US   18599.714077
# 2297        NaN     NaN         St. Louis, Missouri, US   18638.610749
# 2425        NaN     NaN           Lincoln, Nebraska, US   19771.438391
# 2644        NaN     NaN      Durham, North Carolina, US   15363.870502
# 2930        NaN     NaN             Tulsa, Oklahoma, US   19392.926428
# 3024        NaN     NaN  Philadelphia, Pennsylvania, US   17111.808614
# 3052        NaN     NaN        Bayamon, Puerto Rico, US   15057.098465
# 3107        NaN     NaN       San Juan, Puerto Rico, US   14697.856118
# 3126        NaN     NaN    Providence, Rhode Island, US   26921.060334
# 3138        NaN     NaN  Charleston, South Carolina, US   20786.036178
# 3347        NaN     NaN               Austin, Texas, US   14597.762387
# 3396        NaN     NaN               Dallas, Texas, US   18731.663932
# 3452        NaN     NaN              Houston, Texas, US   14176.245211
# 3632        NaN     NaN         Arlington, Virginia, US   13729.828324
# 3649        NaN     NaN        Chesapeake, Virginia, US   16293.830539
# 3710        NaN     NaN           Norfolk, Virginia, US   13842.268746
# 3729        NaN     NaN          Richmond, Virginia, US   23539.842624
# 3749        NaN     NaN    Virginia Beach, Virginia, US   15841.804193
# 3790        NaN     NaN         Spokane, Washington, US   17015.367312
# 3895        NaN     NaN        Milwaukee, Wisconsin, US   23268.367371
#
#       Case_Fatality_Ratio
# 721              1.549336
# 723              1.804309
# 744              0.593553
# 876              1.358346
# 885              1.334719
# 904              0.802749
# 905              0.783740
# 943              0.802737
# 1240             0.746440
# 1252             1.260023
# 1515             1.473037
# 1690             2.185792
# 1901             1.804591
# 1937             1.711673
# 2142             1.387675
# 2247             1.124893
# 2297             1.526664
# 2425             0.869187
# 2644             0.550685
# 2930             1.447509
# 3024             1.607381
# 3052             0.000000
# 3107             0.000000
# 3126             1.317388
# 3138             0.896919
# 3347             1.322993
# 3396             1.183975
# 3452             2.794840
# 3632             0.876438
# 3649             0.957561
# 3710             1.107110
# 3729             0.800377
# 3749             0.852926
# 3790             1.311885
# 3895             0.843880

# %%
df[df['Combined_Key'].isin(largest_per_state['Combined_Key'])]
# 2124  2020-04-12 23:18:00  33.034846 -116.736533       1804      45
# 2125  2020-04-12 23:18:00  37.752151 -122.438567        886      11
# 2241  2020-04-12 23:18:00  47.621131 -117.404649        274      15
# 2262  2020-04-12 23:18:00  38.637700  -90.445837       1633      42
# 2403  2020-04-12 23:18:00  36.119396  -95.940139        332      18
# 2506  2020-04-12 23:18:00  36.732857  -76.045669        243       1
# 2682  2020-04-12 23:18:00  42.350270  -71.904934       2032      49
#
#       Recovered  Active                    Combined_Key
# 48            0     123           Anchorage, Alaska, US
# 72            0     364         Arlington, Virginia, US
# 95            0      10               Austin, Texas, US
# 105           0    1227         Baltimore, Maryland, US
# 387           0     337  Charleston, South Carolina, US
# 413           0     121        Chesapeake, Virginia, US
# 616           0    1675               Dallas, Texas, US
# 662           0    1201            Denver, Colorado, US
# 663           0       4            Des Moines, Iowa, US
# 711           0     277      Durham, North Carolina, US
# 845           0     205          Fresno, California, US
# 1080          0     344            Honolulu, Hawaii, US
# 1154          0     135        Jackson, Mississippi, US
# 1238          0     300       Kansas City, Missouri, US
# 1408          0      16           Lincoln, Nebraska, US
# 1442          0    8625     Los Angeles, California, US
# 1632          0    1622        Milwaukee, Wisconsin, US
# 1646          0     426             Mobile, Alabama, US
# 1673          0     116         Montgomery, Alabama, US
# 1747          0   96310     New York City, New York, US
# 1770          0      90           Norfolk, Virginia, US
# 1910          0    6356  Philadelphia, Pennsylvania, US
# 1996          0    1217    Providence, Rhode Island, US
# 2059          0       5          Richmond, Virginia, US
# 2124          0    1759       San Diego, California, US
# 2125          0     875   San Francisco, California, US
# 2241          0     259         Spokane, Washington, US
# 2262          0    1591         St. Louis, Missouri, US
# 2403          0     314             Tulsa, Oklahoma, US
# 2506          0     242    Virginia Beach, Virginia, US
# 2682          0    1983    Worcester, Massachusetts, US

# %%
# Cols from 2022 data:

FIPS,Admin2,Province_State,Country_Region,Last_Update,Lat,Long_,Confirmed,Deaths,Recovered,Active,Combined_Key,Incident_Rate,Case_Fatality_Ratio

# %%
# Cols from early 2020 data:

FIPS	Admin2	Province_State	Country_Region	Last_Update	Lat	Long_	Confirmed	Deaths	Recovered	Active	Combined_Key

# %%
# Drop rows we're not interested in (e.g. The Cruise Ships with outbreaks, Minor Outlying US Territories)
df = df[~df['Province_State'].isin(['Diamond Princess', 'Grand Princess', 'American Samoa', 'Recovered', 'Virgin Islands'])]

# Account for slight modifications to column nomenclature that occurred over time
if 'Mortality_Rate' in df.columns:
    df.rename({'Mortality_Rate' : 'Case_Fatality_Ratio', 'People_Tested' : 'Total_Test_Results'}, axis=1, inplace=True)

df = df.iloc[:, 0:14].drop(columns=['Recovered', 'Active', 'FIPS', 'Total_Test_Results', 'People_Hospitalized'])

# Fix problem where Case_Fatality_Ratio was left NULL in some cases before any deaths accrued
# df['Case_Fatality_Ratio'] = df.apply(lambda x: 0 if x['Deaths'] == 0 else x['Case_Fatality_Ratio'], axis=1)

# drop data into database
# df.to_sql('city_data', con, if_exists='append', index=False)
